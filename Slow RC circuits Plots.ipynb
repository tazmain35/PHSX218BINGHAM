# %%
import numpy as np
import matplotlib.pyplot as plt


#Experiment 1- Plotting Charging and Discharging Curves----------------------------------

##CHARGING CURVE

V = np.array ([3.997,6.34,7.93,8.99,9.71,10.18,10.49,10.69,10.82,10.91,10.95,10.97])
t = np.array ([10.06,20.11,30.06,40.02,50.06,60.01,70.06,80.06,90.1,100.06,110.1,120.06])

plt.plot (t,V)

x = t
y = V

plt.xlabel('t for time in seconds')
plt.ylabel('V for Volts')
plt.title('RB Capacitor Charge Curve')

plt.show()

# %%
##DISCHARGING CURVE

V = np.array ([8.18,5.61,3.861,2.698,1.87,1.3,0.907,0.635,0.452,0.32,0.229,0.165])
t = np.array ([10,20.05,30.05,40.05,50.05,60.05,70.05,80.05,90.05,100.05,110.05,120.05])

plt.plot(t,V)

x = t
y = V

plt.xlabel('t for time in seconds')
plt.ylabel('V for Volts')
plt.title('RB Capacitor Discharge Curve')

plt.show()
